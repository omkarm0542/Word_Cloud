# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sample-sales-data/sales_data_sample.csv
# /kaggle/input/json-tabulate-word-cloud/__results__.html
# /kaggle/input/json-tabulate-word-cloud/superheroes.json
# /kaggle/input/json-tabulate-word-cloud/__notebook__.ipynb
# /kaggle/input/json-tabulate-word-cloud/__output__.json
# /kaggle/input/json-tabulate-word-cloud/custom.css
# /kaggle/input/json-tabulate-word-cloud/__results___files/__results___27_0.png
# /kaggle/input/dataset/hours.csv
# /kaggle/input/dataset/superheroes.json
# /kaggle/input/dataset/ecom_sales.csv
# /kaggle/input/dataset/nba.csv
# /kaggle/input/dataset/sample.xlsx
# /kaggle/input/big-bang-theory-episodes/big_bang_theory_episodes.csv
# /kaggle/input/big-bang-theory-episodes/big_bang_theory_imdb.csv
# /kaggle/input/heart-disease-classifications-machine-learning/__results__.html
# /kaggle/input/heart-disease-classifications-machine-learning/__resultx__.html
# /kaggle/input/heart-disease-classifications-machine-learning/__notebook__.ipynb
# /kaggle/input/heart-disease-classifications-machine-learning/heartDiseaseAndAges.png
# /kaggle/input/heart-disease-classifications-machine-learning/__output__.json
# /kaggle/input/heart-disease-classifications-machine-learning/custom.css
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___8_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___15_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___14_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___10_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___70_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___43_1.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___51_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___16_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___17_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___18_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___13_0.png
# /kaggle/input/heart-disease-classifications-machine-learning/__results___files/__results___75_0.png

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
# Reads 'Youtube04-Eminem.csv' file
df = pd.read_csv('/kaggle/input/dataset/ecom_sales.csv',sep='\n')
df.rename(columns={'linear regression':'column'},inplace=True)
for i in df.index:
    splited =df.iloc[i,0].split('.')
    if len(splited)>1:
        df.iloc[i,0]=splited[1]
    else:
        df.iloc[i,0]=splited[0].strip()
#     print(df.iloc[i,0])
        
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.iloc[:,0]:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
